# %%
import pandas as pd

# %%
df = pd.read_csv("OriginalData/languages.csv")
df
# Out:
#        user_id   language           proficiency
# 0            8  İngilizce     full_professional
# 1            8     Türkçe   native_or_bilingual
# 2            8  Fransızca            elementary
# 3           10  ingilizce                   NaN
# 4           11    Turkish   native_or_bilingual
# ...        ...        ...                   ...
# 76057    66271    English                   NaN
# 76058    66272    English  professional_working
# 76059    66273     Türkçe   native_or_bilingual
# 76060    66273  İngilizce  professional_working
# 76061    66273    Almanca            elementary
#
# [76062 rows x 3 columns]

# %% [markdown]
# Fix up proficiencies

# %%
profs = df.proficiency.unique()
profs
# Out:
# array(['full_professional', 'native_or_bilingual', 'elementary', nan,
#        'professional_working', 'limited_working'], dtype=object)

# %% [markdown]
# Replace with numerical values as such:
# - nan:default_nan, currently set as 2
# - elementary:1
# - limited working:2
# - professional working:3
# - full_professional:4
# - native_or_bilingual:5

# %%
default_nan = 2
df.proficiency.replace(profs,[4,5,1,default_nan,3,2],inplace=True)

# %% [markdown]
# Clear up Languages

# %%
langs = df.language.unique().tolist()
langs.sort()
langs
# Out:
# [' English',
#  ' German',
#  '-English',
#  '1- French',
#  '2- English',
#  '3- Turkish',
#  'ALMANCA',
#  'Advanced English',
#  'Adıge dili',
#  'Afan Oromo',
#  'Al Bakiyye & Hûrayca',
#  'Albanian',
#  'Almanca',
#  'Almanca ',
#  'Almanca (Düşük Seviye)',
#  'Almanca (IAnfänger A2) (Elementary)',
#  'Almanca (basic)',
#  'Almanca (başlangıç)',
#  'Almanca / Deutsch',
#  'Almanca B2',
#  'Almanca(A1)',
#  'Almanca(Beginner)',
#  'Almanca, Eski Yüksek (yaklaşık 750-1050)',
#  'Almanca, Orta Yüksek (yaklaşık 1050-1500)',
#  'Almanca/German',
#  'Amazigh (Language of Berber) ',
#  'Amharic',
#  'Anglais',
#  'Antik Yunanca ',
#  'Antik Yunanca (1453’e kadar)',
#  'Arabe',
#  'Arabic',
#  'Arabic (only very basic speaking skills)',
#  'Arabish',
#  'Arapca',
#  'Arapca ',
#  'Arapça',
#  'Arapça ',
#  'Arapça(Temel Düzeyde)',
#  'Arapça-A1-A2',
#  'Armenian',
#  'Arnavutça',
#  'Assembly',
#  'Avaric Маг|арул мац|',
#  'Azerbaijani',
#  'Azerbaycan Türkçesi',
#  'Azerbaycanca',
#  'Azeri',
#  'Azerice',
#  'Azərbaycan',
#  'Azərbaycan Dili',
#  'BCE',
#  'Bahasa Indonesia',
#  'Bahasa Melayu',
#  'Basa Sunda',
#  'Başlangıç seviyesinde İspanyolca',
#  'Belarusian',
#  'Bengali',
#  'Bokmål, Norsk',
#  'Bokmål, Norveç',
#  'Bokmål, Norwegian',
#  'Bosanski',
#  'Bosnian',
#  'Bosnian ',
#  'Boşnakça',
#  'Brazilian Portuguese',
#  'Bulgarca',
#  'Bulgarian',
#  'C',
#  'C#',
#  'C++',
#  'CHINESE',
#  'Cat Language',
#  'Catalan',
#  'Central Khmer',
#  'Chinese',
#  'Chinese (Simplified)',
#  'Chinese(Simplified-Mandarin) - 中文',
#  'Circassian',
#  'Coldfusion',
#  'Crimean Tatar',
#  'Croatian',
#  'Cymraeg',
#  'Czech',
#  'Czech Language',
#  'Danca',
#  'Danish',
#  'Dari / Persian (native speaker)',
#  'Deutch',
#  'Deutsch',
#  'Deutsch ',
#  'Deutsch - B1',
#  'Deutsche',
#  'Didinga (Native)',
#  'Dutch',
#  'Dutch (beginner)',
#  'ENGLISH',
#  'Elementary Chinese',
#  'En',
#  'Endonezya dili',
#  'Engilish,',
#  'Engish',
#  'Englis',
#  'Englisch',
#  'English',
#  'English ',
#  'English (Advanced)',
#  'English (B2)',
#  'English (B2, Upper-Intermediate)',
#  'English (US)',
#  'English (Upper-Intermediate)',
#  'English - (YDS : 93,75)',
#  'English - Global Village Sydney Australia',
#  'English - Professional working proficiency',
#  'English C1',
#  'English UK',
#  'English US',
#  'English upper intermediate',
#  'English(advanced)',
#  'English,',
#  'English, Advanced',
#  'English, Deutsch',
#  'English, Middle (1100-1500)',
#  'English, Old (ca.450-1100)',
#  'English, Pre-Advance',
#  'English-B2 Upper Intermediate',
#  'English. French ',
#  'Ermenice',
#  'Espanol',
#  'Español',
#  'Español ',
#  'Español, Castellano',
#  'Espańol',
#  'Esperanto',
#  'Estonca',
#  'Estonian',
#  'Farsca',
#  'Farsi',
#  'Farsça',
#  'Felemenkçe',
#  'Felemenkçe, Orta (yaklaşık 1050-1350)',
#  'Fince',
#  'Finnish',
#  'Finnish ',
#  'Francais',
#  'France',
#  'Fransa',
#  'Fransizca',
#  'Fransız',
#  'Fransızca',
#  'Fransızca(Université Galatasaray)',
#  'Fransızca, Eski (842-yaklaşık 1400)',
#  'Fransızca, Orta (yaklaşık 1400-1600)',
#  'Französisch',
#  'Français',
#  'French',
#  'French ',
#  'French (Beginner)',
#  'GERMAN',
#  'Georgian',
#  'German',
#  'German ',
#  'German (A2)',
#  'German (Beginner)',
#  'German (Deutsches Sprachdiplom - 2.Stufe)',
#  'German (Intermediate)',
#  'German Language',
#  'German(beginner)',
#  'German,',
#  'German, B2.2 Goethe Instıtut - İZMİR',
#  'Germanic languages',
#  'Germany',
#  'Gerrman',
#  'Goethe-Zertifikat A2 - 76',
#  'Greek',
#  'Greek, Ancient (to 1453)',
#  'Grek',
#  'Gürcüce',
#  'HTML',
#  'Hausa',
#  'Hebrew',
#  'Hindi',
#  'Hungarian',
#  'Hırvatça',
#  'IELTS',
#  'INGILIZCE',
#  'ISPANYOLCA',
#  'Indonesian',
#  'Ingilizce',
#  'Ingilizce ',
#  'Ingles',
#  'Inglizce',
#  'Irish',
#  'Isvecce',
#  'Italian',
#  'Italiano',
#  'Italien',
#  'Italyanca',
#  'Japanese',
#  'Japanese (Roomaji)',
#  'Japanese(Beginner)',
#  'Japanesse(Roomaji)',
#  'Japonca',
#  'Japonca | A1',
#  'Java',
#  'JavaScript',
#  'Javanese',
#  'Kabardian',
#  'Kafkas dilleri',
#  'Kazakh',
#  'Kazakça',
#  'Kiswahili',
#  'Korean',
#  'Korece',
#  'Korece | A2',
#  'Kotlin',
#  'Kumyk Къумукъ Къумукъча',
#  'Kurdish',
#  'Kurdî',
#  'Kyrgyz',
#  'Kürtçe',
#  'Kırgızca',
#  'Kırım Tatarcası',
#  'Latin',
#  'Latin (Beginner)',
#  'Latince',
#  'Latvian',
#  'Laz Language',
#  'Lazca',
#  'Lazuri',
#  'Lehçe',
#  'Lehçe Polish',
#  'Lithuanian',
#  'Litvanyaca',
#  'Luganda',
#  'Luo (Kenya and Tanzania)',
#  'Macarca',
#  'Macedonian',
#  'Magyar',
#  'Makedonca',
#  'Makedonski',
#  'Malay',
#  'Malay dili',
#  'Maltese',
#  'Mandarin ',
#  'Mesleki İng.',
#  'Mesleki İngilizce',
#  'Mongolian',
#  'Montenegrin',
#  'Ms Sql (Sorgu dili)',
#  'Napolitano',
#  'Nogayca',
#  'Norse, Old',
#  'Norveççe',
#  'Norwegian',
#  'Objective-C',
#  'Osmanische Sprachen',
#  'Osmanlı Türkçesi',
#  'Osmanlıca',
#  'Ottoman Turkish',
#  'PHP',
#  'PL/SQL',
#  'Pashto',
#  'Persian',
#  'Polish',
#  'Polski',
#  'Portekizce',
#  'Portuguese',
#  'Português',
#  'Powerbuilder',
#  'Punjabi',
#  'Pushto',
#  'Python',
#  'Pусский',
#  'RScript',
#  'Regex',
#  'Romaic',
#  'Romanca',
#  'Romanian',
#  'Romence',
#  'Român (Romanian Language)',
#  'Rumence',
#  'Rusca',
#  'Russain',
#  'Russe',
#  'Russian',
#  'Russian ',
#  'Russian Русский Язык',
#  'Russian(Certified)',
#  'Rusça',
#  'Rusça ',
#  'Rusça (Beginner A1)',
#  'SPANISH',
#  'SQL',
#  'Sarcasm',
#  'Serbian',
#  'Sign Languages',
#  'Sinhalese',
#  'Slavic languages',
#  'Slovak',
#  'Slovakça',
#  'Slovene',
#  'Slovenian',
#  'Soma',
#  'Somali',
#  'South Sudanese Arabic',
#  'Spani',
#  'Spanish',
#  'Srpski',
#  'StyleSheet',
#  'Swahili',
#  'Swedish',
#  'Swiss German (Schweizerdeutsch)',
#  'Sırpça',
#  'TURKISH',
#  'Tajik',
#  'Tamazight',
#  'Tamil',
#  'Tatar',
#  'Tatarca',
#  'Thai',
#  'Tunisian',
#  'Turc',
#  'Turk',
#  'Turkce',
#  'Turkish',
#  'Turkish ',
#  'Turkish (Native Speaker), English (Intermediate)',
#  'Turkish (Native)',
#  'Turkish (mother tongue)',
#  'Turkish - Native',
#  'Turkish Sign Language',
#  'Turkish(native)',
#  'Turkish,',
#  'Turkish, English',
#  'Turkish, Ottoman (1500-1928)',
#  'Turkish-Mother Language',
#  'Turkish:',
#  'Turkmen',
#  'Turkmence',
#  'Turksih',
#  'Turkçe',
#  'Turkısh',
#  'TÜRKÇE',
#  'Tükçe',
#  'Türk',
#  'Türk İşaret Dili',
#  'Türkce',
#  'Türke',
#  'Türkisch',
#  'Türkish',
#  'Türkmen',
#  'Türkmence',
#  'Türkmençe',
#  'Türkçe',
#  'Türkçe ',
#  'Türkçe (Turkish)',
#  'Türkçe - İngilizce',
#  'Türkçe / Turkish',
#  'Türkçe İşaret Dili',
#  'Türkçe,',
#  'Türkçe, Osmanlıca (1500-1928)',
#  'Türkçe/Turkish',
#  'Ukrainian',
#  'Ukranian',
#  'Ukraynaca',
#  'Urdu',
#  'Uyghur',
#  'Uzbek',
#  'VB.NET',
#  'VMware ESX',
#  'Wollof',
#  'Yunanca',
#  'YÖKDİL 2017   85',
#  'Zazaki',
#  'Zazaki dili',
#  'almanca',
#  'arabic',
#  'arapca',
#  'arapça',
#  'c++',
#  'english',
#  'english ',
#  'farsi',
#  'german',
#  'germany',
#  'hrvatski',
#  'ibranice',
#  'ing',
#  'ingilizce',
#  'ingilizce ',
#  'ingilizce (B2)',
#  'ingilizce - başlangıç',
#  'ingilizce(english)',
#  'ingilzce',
#  'inglizce',
#  'ispanyolca',
#  'italian',
#  'italiano',
#  'italyanca',
#  'japonca',
#  'javascript',
#  'kirgizca',
#  'kürdi',
#  'oracle data integrator',
#  'orta düzey İngilizce',
#  'rusca',
#  'russian',
#  'rusça',
#  'tatarca',
#  'turkce',
#  'turkish',
#  'turkmen',
#  'turkçe',
#  'türkçe',
#  'uzbek',
#  'Çağatayca',
#  'Çekçe',
#  'Çekçe ',
#  'Çeçence',
#  'Çince',
#  'Çince (Basitleştirilmiş)',
#  'Çince (Mandarin)',
#  'Çinçe',
#  'Özbekçe',
#  'İNGİLİZCE',
#  'İNGİLİZCE ',
#  'İNGİLİZCE ,ALMANCA',
#  'İbranice',
#  'İng',
#  'İngilice',
#  'İngiliz',
#  'İngilizce',
#  'İngilizce ',
#  'İngilizce %30',
#  'İngilizce ( TOEIC - 725 )',
#  'İngilizce ( orta düzeyde )',
#  'İngilizce (Advanced)',
#  'İngilizce (B1 - B2)',
#  'İngilizce (C1)',
#  'İngilizce (English)',
#  'İngilizce (Upper-Intermediate)',
#  'İngilizce (excellent)',
#  'İngilizce (orta)',
#  'İngilizce ,Almanca ',
#  'İngilizce - IELTS 7',
#  'İngilizce / English',
#  'İngilizce A2',
#  'İngilizce Pre-Intermediate',
#  'İngilizce iyi',
#  'İngilizce | B1',
#  'İngilizce(B2)',
#  'İngilizce(C1)',
#  'İngilizce(Orta Seviye)',
#  'İngilizce(Orta)',
#  'İngilizce,',
#  'İngilizce, B1',
#  'İngilizce, B2',
#  'İngilizce, Eski (yaklaşık 450-1100)',
#  'İngilizce, Orta (1100-1500)',
#  'İngilizce, Orta/İleri Düzey',
#  'İngilizce, Upper Intermediate',
#  'İngilizce, ileri',
#  'İngilizce, iyi',
#  'İngilizce, İleri (2500-3000)',
#  'İngilizce, İyi',
#  'İngilizce, İyi ',
#  'İngilizce, İyi (1100-1500)',
#  'İngilizce, İyi (1500-2000)',
#  'İngilizce, İyi düzeyde',
#  'İngilizce, İyi(1100-1500)',
#  'İngilizce- BELS english school. as upper intermediate',
#  'İngilizce-B1 Wimbledon language academy eğitim sürecindeyim.',
#  'İngilizce-intermediate',
#  'İngilizce/English',
#  'İngilize',
#  'İngilizice',
#  'İngilzce',
#  'İngizce',
#  'İngizice',
#  'İnglilizce',
#  'İnglizce',
#  'İspanyolca',
#  'İspanyolca ',
#  'İspanyolca, Başlangıç',
#  'İsveççe',
#  'İtalian',
#  'İtalyanca',
#  'İşaret Dili',
#  'İşaret Dilleri',
#  'İşaret dili',
#  'Ελληνικά',
#  'Английский',
#  'Арабский',
#  'Казахский',
#  'Крымскотатарский',
#  'Къырымтатар тили (Kırım Tatarcası)',
#  'Кыргызский',
#  'Русский',
#  'Турецкий',
#  'Туркменский',
#  'Украинский',
#  'русский',
#  'עברית',
#  'التركية',
#  'العربية',
#  'اللغة العربية',
#  '■ English ■',
#  '■ Türkçe ■',
#  '中文',
#  '日本の',
#  '학국의',
#  '한국어']

# %% [markdown]
# Group similar languages together, mark all but the most popular languages as "Other"

# %%
from fuzzywuzzy import fuzz
from collections import defaultdict

def group_strings(strings, reference_strings, similarity_threshold):
    groups = defaultdict(list)
    for i, string1 in enumerate(reference_strings):
        for j, string2 in enumerate(strings):
            similarity = fuzz.token_set_ratio(string1, string2)
            if similarity >= similarity_threshold:
                groups[string1].append(string2)
    return groups

# %%
lang_groups = ["English","German", "Turkish", "French", "Spanish", "Chinese",
"İngilizce", "Almanca", "Türkçe", "Fransizca", "İspanyolca", "Çince"]

# %%
groups = group_strings(langs,lang_groups, 75)

# %%
for key in groups.keys():
    print("Key: ", key)
    print("Values: ", groups[key])
    print("-------------------")
# Out:
# Key:  English
# Values:  [' English', '-English', '2- English', 'Advanced English', 'ENGLISH', 'Engilish,', 'Engish', 'Englis', 'Englisch', 'English', 'English ', 'English (Advanced)', 'English (B2)', 'English (B2, Upper-Intermediate)', 'English (US)', 'English (Upper-Intermediate)', 'English - (YDS : 93,75)', 'English - Global Village Sydney Australia', 'English - Professional working proficiency', 'English C1', 'English UK', 'English US', 'English upper intermediate', 'English(advanced)', 'English,', 'English, Advanced', 'English, Deutsch', 'English, Middle (1100-1500)', 'English, Old (ca.450-1100)', 'English, Pre-Advance', 'English-B2 Upper Intermediate', 'English. French ', 'Turkish (Native Speaker), English (Intermediate)', 'Turkish, English', 'english', 'english ', 'ingilizce(english)', 'İngilizce (English)', 'İngilizce / English', 'İngilizce- BELS english school. as upper intermediate', 'İngilizce/English', '■ English ■']
# -------------------
# Key:  German
# Values:  [' German', 'Almanca/German', 'GERMAN', 'German', 'German ', 'German (A2)', 'German (Beginner)', 'German (Deutsches Sprachdiplom - 2.Stufe)', 'German (Intermediate)', 'German Language', 'German(beginner)', 'German,', 'German, B2.2 Goethe Instıtut - İZMİR', 'Germany', 'Gerrman', 'Swiss German (Schweizerdeutsch)', 'german', 'germany']
# -------------------
# Key:  Turkish
# Values:  ['3- Turkish', 'Ottoman Turkish', 'TURKISH', 'Turkish', 'Turkish ', 'Turkish (Native Speaker), English (Intermediate)', 'Turkish (Native)', 'Turkish (mother tongue)', 'Turkish - Native', 'Turkish Sign Language', 'Turkish(native)', 'Turkish,', 'Turkish, English', 'Turkish, Ottoman (1500-1928)', 'Turkish-Mother Language', 'Turkish:', 'Turksih', 'Turkısh', 'Türkisch', 'Türkish', 'Türkçe (Turkish)', 'Türkçe / Turkish', 'Türkçe/Turkish', 'turkish']
# -------------------
# Key:  French
# Values:  ['1- French', 'English. French ', 'French', 'French ', 'French (Beginner)']
# -------------------
# Key:  Spanish
# Values:  ['Danish', 'SPANISH', 'Spani', 'Spanish']
# -------------------
# Key:  Chinese
# Values:  ['CHINESE', 'Chinese', 'Chinese (Simplified)', 'Chinese(Simplified-Mandarin) - 中文', 'Elementary Chinese']
# -------------------
# Key:  İngilizce
# Values:  ['INGILIZCE', 'Ingilizce', 'Ingilizce ', 'Inglizce', 'Mesleki İngilizce', 'Türkçe - İngilizce', 'ingilizce', 'ingilizce ', 'ingilizce (B2)', 'ingilzce', 'inglizce', 'orta düzey İngilizce', 'İNGİLİZCE', 'İNGİLİZCE ', 'İngilice', 'İngiliz', 'İngilizce', 'İngilizce ', 'İngilizce %30', 'İngilizce ( TOEIC - 725 )', 'İngilizce ( orta düzeyde )', 'İngilizce (Advanced)', 'İngilizce (B1 - B2)', 'İngilizce (C1)', 'İngilizce (English)', 'İngilizce (Upper-Intermediate)', 'İngilizce (excellent)', 'İngilizce (orta)', 'İngilizce ,Almanca ', 'İngilizce - IELTS 7', 'İngilizce / English', 'İngilizce A2', 'İngilizce Pre-Intermediate', 'İngilizce iyi', 'İngilizce | B1', 'İngilizce(B2)', 'İngilizce(C1)', 'İngilizce(Orta Seviye)', 'İngilizce(Orta)', 'İngilizce,', 'İngilizce, B1', 'İngilizce, B2', 'İngilizce, Eski (yaklaşık 450-1100)', 'İngilizce, Orta (1100-1500)', 'İngilizce, Orta/İleri Düzey', 'İngilizce, Upper Intermediate', 'İngilizce, ileri', 'İngilizce, iyi', 'İngilizce, İleri (2500-3000)', 'İngilizce, İyi', 'İngilizce, İyi ', 'İngilizce, İyi (1100-1500)', 'İngilizce, İyi (1500-2000)', 'İngilizce, İyi düzeyde', 'İngilizce, İyi(1100-1500)', 'İngilizce- BELS english school. as upper intermediate', 'İngilizce-B1 Wimbledon language academy eğitim sürecindeyim.', 'İngilizce-intermediate', 'İngilizce/English', 'İngilize', 'İngilizice', 'İngilzce', 'İngizce', 'İngizice', 'İnglilizce', 'İnglizce']
# -------------------
# Key:  Almanca
# Values:  ['ALMANCA', 'Almanca', 'Almanca ', 'Almanca (Düşük Seviye)', 'Almanca (IAnfänger A2) (Elementary)', 'Almanca (basic)', 'Almanca (başlangıç)', 'Almanca / Deutsch', 'Almanca B2', 'Almanca(A1)', 'Almanca(Beginner)', 'Almanca, Eski Yüksek (yaklaşık 750-1050)', 'Almanca, Orta Yüksek (yaklaşık 1050-1500)', 'Almanca/German', 'Italyanca', 'almanca', 'italyanca', 'İNGİLİZCE ,ALMANCA', 'İngilizce ,Almanca ']
# -------------------
# Key:  Türkçe
# Values:  ['Turk', 'Turkce', 'Turkçe', 'TÜRKÇE', 'Tükçe', 'Türk', 'Türkce', 'Türke', 'Türkmen', 'Türkçe', 'Türkçe ', 'Türkçe (Turkish)', 'Türkçe - İngilizce', 'Türkçe / Turkish', 'Türkçe İşaret Dili', 'Türkçe,', 'Türkçe, Osmanlıca (1500-1928)', 'Türkçe/Turkish', 'turkce', 'turkçe', 'türkçe', '■ Türkçe ■']
# -------------------
# Key:  Fransizca
# Values:  ['Fransa', 'Fransizca', 'Fransız', 'Fransızca']
# -------------------
# Key:  İspanyolca
# Values:  ['Başlangıç seviyesinde İspanyolca', 'ISPANYOLCA', 'ispanyolca', 'İspanyolca', 'İspanyolca ', 'İspanyolca, Başlangıç']
# -------------------
# Key:  Çince
# Values:  ['Fince', 'Çince', 'Çince (Basitleştirilmiş)', 'Çince (Mandarin)', 'Çinçe']
# -------------------

# %%
other=[]
for lang in langs:
    found=False
    for group in groups.values():
        if lang in group:
            found=True
            break
    if not found:
        other.append(lang)

# %%
english = groups["English"] + groups["İngilizce"]
german = groups["German"] + groups["Almanca"]
turkish = groups["Turkish"] + groups["Türkçe"]
french = groups["French"] + groups["Fransizca"]
spanish = groups["Spanish"] + groups["İspanyolca"]
chinese = groups["Chinese"] + groups["Çince"]

# %% [markdown]
# Now replace the languages in the dataframe

# %%
df.loc[df.language.isin(english), "language"] = "English"
df.loc[df.language.isin(german),"language"] = "German"
df.loc[df.language.isin(turkish),"language"] = "Turkish"
df.loc[df.language.isin(french),"language"] = "French"
df.loc[df.language.isin(spanish),"language"] = "Spanish"
df.loc[df.language.isin(chinese),"language"] = "Chinese"
df.loc[df.language.isin(other),"language"] = "Other"

# %%
lang_important = ["English", "German", "Turkish", "French", "Spanish", "Chinese"]

# %% [markdown]
# ## Further clearing

# %% [markdown]
# Set these languages as columns, with their values being the proficiency (0 if no proficiency), add new column #languages known,

# %%
df.head()
# Out:
#    user_id language  proficiency
# 0        8  English            4
# 1        8  Turkish            5
# 2        8   French            1
# 3       10  English            2
# 4       11  Turkish            5

# %%
n_langs = df["user_id"].value_counts().reset_index().rename(columns={'index': 'user_id', 'user_id': 'N_languages'})

# %%
n_langs.isna().sum()
# Out:
# user_id        0
# N_languages    0
# dtype: int64

# %%
for lang in lang_important:
    df[lang] = 0

for lang in lang_important:
    mask = df['language'] == lang
    df.loc[mask, lang] = df.loc[mask, 'proficiency']

# %%
df.drop(columns=["language", "proficiency"], inplace=True)

# %%
df = df.groupby('user_id').sum().reset_index()

# %%
df["NLanguages"] = n_langs["N_languages"]

# %%
df
# Out:
#        user_id  English  German  Turkish  French  Spanish  Chinese  NLanguages
# 0            8        4       0        5       1        0        0          13
# 1           10        2       0        0       0        0        0          12
# 2           11        3       0        5       0        0        0          12
# 3           12        3       0        5       0        0        0          12
# 4           13        4       2        0       0        0        0          12
# ...        ...      ...     ...      ...     ...      ...      ...         ...
# 37285    66265        2       0        0       0        0        0           1
# 37286    66269        2       0        0       0        0        0           1
# 37287    66271        2       0        0       0        0        0           1
# 37288    66272        3       0        0       0        0        0           1
# 37289    66273        3       1        5       0        0        0           1
#
# [37290 rows x 8 columns]

# %% [markdown]
# Save

# %%
df.to_csv("PreparedData/Languages.csv", index=False)
